# %% [markdown]
# # Resultados e exemplos de uso
#
# Arquivos que compôem o programa e suas funções:
# * classDinamica - equações e cálculos (principal)
# * constants.py - constantes e algumas variáveis
# * utils.py - funções úteis usadas para auxiliar o arquivo principal
# * motor.py - função de cálculo de tração do motor do modelo
# * forcas_momentos.py - função com cálculos de forças e momentos

# %%
from classDinamica import *

# Condições iniciais, na ordem: delta_profundor, delta_aileron, delta_leme, pi_comando, alpha, theta, phi
X0=[0, 0, 0, 0.5, 0.05, 0.1, 0]

# %% [markdown]
# ### 1. Trimagens a H=1000m, V=150m/s, 200m/s e 250m/s. Beta=0. Psip=0.

# %% [markdown]
# a) Vt = 150

# %%
condicoes_voo = [1_000, 150, 0, 0]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.029 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.297 %
#                 alpha: 0.077 rad
#                 theta: 0.077 rad
#                 phi: 0.000 rad
#       f_min: 7.187191835175844e-11

# %% [markdown]
# b) Vt = 200

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10

# %% [markdown]
# c) Vt = 250

# %%
condicoes_voo = [1_000, 250, 0, 0]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.010 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.557 %
#                 alpha: 0.028 rad
#                 theta: 0.028 rad
#                 phi: 0.000 rad
#       f_min: 1.6906761359672158e-10

# %% [markdown]
# ### 2. Trimagens a H=1000m, V=150m/s, beta=-1deg, beta = 1 deg. Psip=0.

# %% [markdown]
# a) Beta = -1°

# %%
condicoes_voo = [1_000, 150, -1, 0]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.029 rad
#                 delta_aileron: 0.001 rad
#                 delta_leme: -0.031 rad
#                 pi_comando: 0.295 %
#                 alpha: 0.077 rad
#                 theta: 0.077 rad
#                 phi: -0.057 rad
#       f_min: 7.165257829773524e-11

# %% [markdown]
# b) Beta = 1°

# %%
condicoes_voo = [1_000, 150, 1, 0]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.029 rad
#                 delta_aileron: -0.001 rad
#                 delta_leme: 0.031 rad
#                 pi_comando: 0.295 %
#                 alpha: 0.077 rad
#                 theta: 0.077 rad
#                 phi: 0.057 rad
#       f_min: 7.27351327984476e-11

# %% [markdown]
# ### 3. Trimagens a H=1000m, V=150m/s, psip=-0.5deg/s e psip=+0.5deg/s. Beta=0.

# %% [markdown]
# a) psip = -0.5 °/s

# %%
condicoes_voo = [1_000, 150, 0, -0.5]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.029 rad
#                 delta_aileron: 0.000 rad
#                 delta_leme: 0.004 rad
#                 pi_comando: 0.299 %
#                 alpha: 0.077 rad
#                 theta: 0.077 rad
#                 phi: -0.135 rad
#       f_min: 7.068621457102591e-11

# %% [markdown]
# b) psip = +0.5 °/s

# %%
condicoes_voo = [1_000, 150, 0, 0.5]
tempo_voo = 300
simulacao = simDinamica(condicoes_voo, tempo_voo)
valEquilibrio = simulacao.calcEquilibrio(X0=X0)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.029 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.004 rad
#                 pi_comando: 0.299 %
#                 alpha: 0.077 rad
#                 theta: 0.077 rad
#                 phi: 0.135 rad
#       f_min: 7.152486498477465e-11

# %% [markdown]
# ## Respostas às perturbações
#
# Foram consideradas as condições para H = 1_000m, Vt = 200m/s, beta=0 e psip=0.

# %% [markdown]
# ### 4. Resposta a perturbação em aoa = 1 deg.  t=10s.

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 10
perturbacao = [
    0, #DVt
    +1, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]
simulacao = simDinamica(condicoes_voo, tempo_voo)
simulacao.runSimulation(
    X0_equilibrio             = X0,
    perturbacao               = perturbacao
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__Dalpha1.png

# %% [markdown]
# ### 5. Resposta a perturbação em beta=1deg. t=8s.

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 8
perturbacao = [
    0, #DVt
    0, #Dalpha
    1, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]
simulacao = simDinamica(condicoes_voo, tempo_voo)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio             = X0,
    perturbacao               = perturbacao
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__Dbeta1.png

# %% [markdown]
# ### 6. Resposta a perturbação em V=9m/s. t= 300s.

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 300
perturbacao = [
    9, #DVt
    0, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]
simulacao = simDinamica(condicoes_voo, tempo_voo)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio             = X0,
    perturbacao               = perturbacao
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__DVt9.png

# %% [markdown]
# ### 7. Resposta a perturbação em p=10deg/s . t= 6s

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 6
perturbacao = [
    0, #DVt
    0, #Dalpha
    0, #Dbeta
    10, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]
simulacao = simDinamica(condicoes_voo, tempo_voo)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio             = X0,
    perturbacao               = perturbacao
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__Dp10.png

# %% [markdown]
# ### 8. Resposta a doublet de profundor. Tempo = 10s. (passos de 1s).

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 10
perturbacao = [
    0, #DVt
    0, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]

vet_tempo     = [0, 0.9, 1.0, 1.9, 2.0, 2.9, 3.0, 10]
doublet       = [0,   0,   1,   1,  -1,  -1,   0,  0]

simulacao = simDinamica(
    condicoesVoo    = condicoes_voo,
    tempo_voo       = tempo_voo,
    vet_tempo       = vet_tempo,
    doublet         = doublet,
    superficie_doublet = 'profundor'
)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio   = X0,
    perturbacao     = perturbacao,
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__doublet_profundor.png

# %% [markdown]
# ### 9. Resposta a doublet de aileron. Tempo = 10s. (passos de 1s).

# %%
condicoes_voo = [1_000, 200, 0, 0]
tempo_voo = 10
perturbacao = [
    0, #DVt
    0, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]

vet_tempo     = [0, 0.9, 1.0, 1.9, 2.0, 2.9, 3.0, 10]
doublet       = [0,   0,   1,   1,  -1,  -1,   0,  0]

simulacao = simDinamica(
    condicoesVoo    = condicoes_voo,
    tempo_voo       = tempo_voo,
    vet_tempo       = vet_tempo,
    doublet         = doublet,
    superficie_doublet = 'aileron'
)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio   = X0,
    perturbacao     = perturbacao,
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__doublet_aileron.png

# %% [markdown]
# ### 10. Resposta a doublet de leme. Tempo = 10s. (passos de 1s).

# %%
condicoes_voo = [1_000, 200, 0, 0]
perturbacao = [
    0, #DVt
    0, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]
# tempo de voo deve ser igual ao ultimo item de vet_tempo caso deseja-se rodar simulação de doublet
tempo_voo = 10
vet_tempo     = [0, 0.9, 1.0, 1.9, 2.0, 2.9, 3.0, 10]
doublet       = [0,   0,   1,   1,  -1,  -1,   0,  0]

simulacao = simDinamica(
    condicoesVoo    = condicoes_voo,
    tempo_voo       = tempo_voo,
    vet_tempo       = vet_tempo,
    doublet         = doublet,
    superficie_doublet = 'leme'
)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio   = X0,
    perturbacao     = perturbacao,
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__doublet_leme.png

# %% [markdown]
# ### 11. Resposta a doublet de tração. Tempo = 10s. (passos de 1s).

# %%
condicoes_voo = [1_000, 200, 0, 0]
perturbacao = [
    0, #DVt
    0, #Dalpha
    0, #Dbeta
    0, #Dp
    0, #Dq
    0, #Dr
    0, #Dpsi
    0, #Dtheta
    0, #Dphi
    0, #Dh
]

vet_tempo     = [0,   0.9, 1.0, 1.9, 2.0, 2.9, 3.0,  10, 300]
doublet       = [0.4, 0.4, 0.8, 0.8, 0.0, 0.0, 0.4, 0.4, 0.4]
tempo_voo = 300

simulacao = simDinamica(
    condicoesVoo    = condicoes_voo,
    tempo_voo       = tempo_voo,
    vet_tempo       = vet_tempo,
    doublet         = doublet,
    superficie_doublet = 'tracao'
)
# OPÇÃO DE RODAR DIRETAMENTE
simulacao.runSimulation(
    X0_equilibrio   = X0,
    perturbacao     = perturbacao,
)
# Out:
# Rodando minimização da função de equilíbrio...
#       Valores encontrados para voo em equilíbrio:
#                 delta_profundor: -0.016 rad
#                 delta_aileron: -0.000 rad
#                 delta_leme: -0.000 rad
#                 pi_comando: 0.393 %
#                 alpha: 0.043 rad
#                 theta: 0.043 rad
#                 phi: 0.000 rad
#       f_min: 1.0902547947938948e-10
# Rodando cálculo da função de dinâmica...
#     Solução encontrada
# Gráfico salvo na pasta:
# c:\Users\gabri\OneDrive\Faculdade\2023.1\EMA017T - PRINCIPIOS DA DINAMICA DE VOOS E CONTROLE DA AERONAVE\simulacao_dinamica_aeronaves\results\simDim__doublet_tracao.png

# %% [markdown]
# ------------------------
